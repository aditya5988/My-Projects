# %%
import pandas as pd

# %%
df=pd.read_csv('car_prices.csv')
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# Task 1
low=df[(df.year==2014)]
low_mean=(low.groupby(by='make')['sellingprice'].mean()).sort_values()
print("The top five low priced cars are = ")
low_mean.head()
# Out:
# The top five low priced cars are =
# make
# smart          8620.000000
# FIAT          12585.109290
# Mitsubishi    13502.323838
# Kia           14341.490037
# Volkswagen    14840.196850
# Name: sellingprice, dtype: float64

# %%
#  Task 2
bmw_2010=df[(df.make=='BMW')&(df.year==2010)&(df.condition>4.5)]
bmw_mean=bmw_2010.groupby(by=['make'])['sellingprice'].mean()
bmw_mean
# Out:
# make
# BMW    23572.222222
# Name: sellingprice, dtype: float64

# %%
bmw_2015=df[(df.make=='BMW')&(df.year==2015)&(df.condition>4.5)]
bmw_mean15=bmw_2015.groupby(by=['make'])['sellingprice'].mean()
bmw_mean15
# Out:
# make
# BMW    42994.68599
# Name: sellingprice, dtype: float64

# %%
perc=((bmw_mean15-bmw_mean)/bmw_mean15)*100

print("BMW car in 2015 has a selling price of 45.1741 % more than selling price in 2010", perc)
# Out:
# BMW car in 2015 has a selling price of 45.1741 % more than selling price in 2010 make
# BMW    45.174103
# Name: sellingprice, dtype: float64

# %%
# Task 3
col=df[(df.interior=='black')]
col_black=col.groupby(by=['interior'])['mmr'].mean()
col_black
# Out:
# interior
# black    15858.520055
# Name: mmr, dtype: float64

# %%
col1=df[(df.interior=='gray')]
col_gray=col1.groupby(by=['interior'])['mmr'].mean()
col_gray
# Out:
# interior
# gray    11189.776545
# Name: mmr, dtype: float64

# %%
diff_col=(15858.520055 - 11189.776545)
print("Difference between wholesale price of cars with black and gray interiors are :", diff_col)
# Out:
# Difference between wholesale price of cars with black and gray interiors are : 4668.74351

# %%
# Task 4
l=df[(df.year>=2013)&(df.year<=2015)]
l
# Out:
#         year    make                model        trim       body transmission  \
# 0       2015     Kia              Sorento          LX        SUV    automatic
# 1       2015     Kia              Sorento          LX        SUV    automatic
# 2       2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3       2015   Volvo                  S60          T5      Sedan    automatic
# 4       2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...      ...     ...                  ...         ...        ...          ...
# 558826  2014    Jeep       Grand Cherokee     Limited        SUV    automatic
# 558827  2014    Jeep       Grand Cherokee      Laredo        SUV    automatic
# 558832  2015     Kia                 K900      Luxury      Sedan          NaN
# 558835  2015  Nissan               Altima       2.5 S      sedan    automatic
# 558836  2014    Ford                F-150         XLT  SuperCrew    automatic
#
# ...

# %%
g=pd.pivot_table(l,index=['color'], values=['make'],aggfunc=['count'])
g
# Out:
#            count
#             make
# color
# beige       1686
# black      35563
# blue       13744
# brown       2672
# burgundy    2486
# charcoal     187
# gold        1744
# gray       29464
# green       2096
# lime           8
# off-white    375
# orange       583
# pink          29
# purple       397
# red        17230
# silver     26143
# turquoise     35
# white      40055
# yellow       262
# —          12801

# %%
# pd.crosstab(l.make,l.color, rownames=['manufacturers'], colnames=['colours'])

# %%
# Task 5
suv_14=df[(df.body=='SUV')&(df.saledate=='Fri Dec 19 2014 09:00:00 GMT-0800 (PST)')]
suv_sum14=suv_14.groupby(by=['body'])['sellingprice'].count()
suv_sum14
# Out:
# body
# SUV    569
# Name: sellingprice, dtype: int64

# %%
suv_15=df[(df.body=='SUV')&(df.saledate=='Thu Jan 15 2015 04:30:00 GMT-0800 (PST)')]
suv_sum15=suv_15.groupby(by=['body'])['sellingprice'].count()
suv_sum15
# Out:
# body
# SUV    310
# Name: sellingprice, dtype: int64

# %%
q=569
v=310
w=((569-310)/569)*100
print("The sales of SUV from Fri Dec 19 2014 09:00:00 GMT-0800 (PST) has decreased by ", w,"% till Thu Jan 15 2015 04:30:00 GMT-0800 (PST) ")
# Out:
# The sales of SUV from Fri Dec 19 2014 09:00:00 GMT-0800 (PST) has decreased by  45.518453427065026 % till Thu Jan 15 2015 04:30:00 GMT-0800 (PST)

# %%
# Task 6
import numpy as np
df.insert(15,'Discounted_Price',np.nan)
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df.loc[df['make']=='Ford','Discounted_Price']= df.sellingprice*.9
df.loc[df['make']=='chevrolet','Discounted_Price']= df.sellingprice*.9
df.loc[(df['make']!='Ford') & (df['make']!='chevrolet'),'Discounted_Price']=df.sellingprice*.8
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# Task 7
df2=df
df2=df2.drop(['saledate','vin'], axis=1)
df2
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer   color interior  \
# 0         automatic    ca        5.0   16639.0   white    black
# ...

# %%
print(df2.isnull().sum())
print(df2.info())
# Out:
# year                    0
# make                10301
# model               10399
# trim                10651
# body                13195
# transmission        65353
# state                   1
# condition           11794
# odometer               94
# color                 749
# interior              749
# seller                  0
# mmr                     0
# sellingprice            0
# Discounted_Price        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year              558837 non-null  int64
#  1   make              548536 non-null  object
#  2   model             548438 non-null  object
#  3   trim              548186 non-null  object
#  4   body              545642 non-null  object
#  5   transmission      493484 non-null  object
#  6   state             558836 non-null  object
# ...

# %%
print(df2['make'].value_counts())
# Out:
# Ford          93554
# Chevrolet     60197
# Nissan        53946
# Toyota        39871
# Dodge         30710
#               ...
# airstream         1
# dot               1
# hyundai tk        1
# mazda tk          1
# Lotus             1
# Name: make, Length: 96, dtype: int64

# %%
df2['make']=df['make'].fillna('Ford')

# %%
print(df2['model'].value_counts())
# Out:
# Altima        19349
# F-150         14479
# Fusion        12946
# Camry         12545
# Escape        11861
#               ...
# siera             1
# avalon            1
# c240s             1
# allure            1
# 458 Italia        1
# Name: model, Length: 973, dtype: int64

# %%
df2['model']=df['model'].fillna('Altima')

# %%
print(df2['trim'].value_counts())
# Out:
# Base                 55817
# SE                   43648
# LX                   20757
# Limited              18356
# LT                   16915
#                      ...
# 4x2 reg silver ls        1
# 25 4x4 cr sle            1
# xl                       1
# 4x4 v6 xlt sport         1
# Power Wagon              1
# Name: trim, Length: 1972, dtype: int64

# %%
df2['trim']=df['trim'].fillna('Base')

# %%
print(df2['body'].value_counts())
# Out:
# Sedan          199437
# SUV            119292
# sedan           41906
# suv             24552
# Hatchback       21380
#                 ...
# Ram Van             1
# CTS-V Wagon         1
# g37 coupe           1
# cab plus 4          1
# cts wagon           1
# Name: body, Length: 87, dtype: int64

# %%
df2['body']=df['body'].fillna('Sedan')

# %%
print(df2['transmission'].value_counts())
# Out:
# automatic    475914
# manual        17544
# sedan            15
# Sedan            11
# Name: transmission, dtype: int64

# %%
df2['transmission']=df['transmission'].fillna('automatic')

# %%
print(df2['state'].value_counts())
# Out:
# fl    82952
# ca    73152
# pa    53909
# tx    45914
# ga    34753
# nj    27784
# il    23486
# nc    21845
# oh    21575
# tn    20895
# mo    16013
# mi    15511
# nv    12685
# va    12029
# md    11158
# wi     9852
# mn     9429
# az     8741
# co     7776
# wa     7416
# ma     6729
# ny     5699
# in     4326
# sc     4252
# ne     4013
# on     3442
# pr     2725
# la     2191
# ms     1853
# ut     1836
# qc     1245
# hi     1237
# or     1155
# ab      928
# nm      171
# ok       72
# ns       61
# al       26
# Name: state, dtype: int64

# %%
df2['state']=df['state'].fillna('fl')

# %%
print(df2['condition'].value_counts())
# Out:
# 1.9    42281
# 3.5    26750
# 3.7    25938
# 4.4    25516
# 4.3    24937
# 4.2    24329
# 3.6    23145
# 4.1    23075
# 2.0    20796
# 4.0    19922
# 3.9    19920
# 2.8    19179
# 2.9    18928
# 3.8    18725
# 3.4    17398
# 2.7    16351
# 4.9    13100
# 4.8    12714
# 4.6    12638
# 2.5    12561
# 4.5    12313
# 2.6    11912
# 4.7    11363
# 5.0    11223
# 3.0    10803
# 3.3    10619
# 3.2     9962
# 2.4     9326
# 3.1     9222
# 2.1     9199
# 2.3     8188
# 1.0     7367
# 2.2     6057
# 1.8      323
# 1.7      243
# 1.6      178
# 1.5      144
# 1.4      134
# 1.2       95
# 1.1       87
# 1.3       82
# Name: condition, dtype: int64

# %%
con_ave=df['condition'].mean()
print(con_ave)
# Out:
# 3.424510504655353

# %%
df2['condition']=df['condition'].fillna(con_ave)

# %%
odo_ave=df['odometer'].mean()
print(odo_ave)
# Out:
# 68320.43754821089

# %%
df2['odometer']=df['odometer'].fillna(odo_ave)

# %%
print(df2['color'].value_counts())
# Out:
# black        110974
# white        106677
# silver        83394
# gray          82860
# blue          51144
# red           43573
# —             24686
# green         11382
# gold          11342
# beige          9222
# burgundy       8972
# brown          6717
# orange         2078
# purple         1561
# off-white      1449
# yellow         1285
# charcoal        479
# turquoise       236
# pink             42
# lime             15
# Name: color, dtype: int64

# %%
df2['color']=df['color'].fillna('black')

# %%
print(df2['interior'].value_counts())
# Out:
# black        244347
# gray         178582
# beige         59758
# tan           44093
# —             17076
# brown          8640
# red            1359
# blue           1138
# silver         1099
# off-white       480
# purple          339
# gold            324
# white           252
# green           245
# burgundy        191
# orange          145
# yellow           20
# Name: interior, dtype: int64

# %%
df2['interior']=df['interior'].fillna('black')

# %%
print(df2.isnull().sum())
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission        0
# state               0
# condition           0
# odometer            0
# color               0
# interior            0
# seller              0
# mmr                 0
# sellingprice        0
# Discounted_Price    0
# dtype: int64
