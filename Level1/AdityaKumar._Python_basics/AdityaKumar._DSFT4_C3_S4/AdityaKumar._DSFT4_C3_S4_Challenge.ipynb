# %%
score =0
#Question 1
answer1 = input("Q1. What is capital of India? \na.  Mumbai \nb.  New Delhi \nc.  Kolkata \nd.  Chennai \nAnswer: ")
if answer1=="b" or answer1=="New Delhi":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is New Delhi.")
    #print("Score :", score)
    print("\n")

    #Question 2
answer2 = input("Q2. Who is President of India? \na.  Narendra Modi \nb.  Ram Nath Kovind \nc.  Sonia Gandhi \nd.  Arvind Kejriwal  \nAnswer: ")
if answer2=="b" or answer2=="Ram Nath Kovind":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Ram Nath Kovind.")
    #print("Score :", score)
    print("\n")
    
#Question 3
answer3 = input("Q3. Where Gateway Of India is Located? \na.  Mumbai \nb.  Bangalore \nc.  Hyderabad \nd.  Lucknow  \nAnswer: ")
if answer3=="a" or answer2=="Mumbai":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Mumbai.")
    #print("Score :", score)
    print("\n")
    
#Question 4
answer4 = input("Q4. Which is the smallest continent? \na.  Asia \nb.  Antartica \nc.  North America \nd.  Australia  \nAnswer: ")
if answer4=="d" or answer4=="Australia":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Australia.")
    #print("Score :", score)
    print("\n")

    #Question 5
answer5 = input("Q5. Which is the largest ocean in the world? \na.  Arctic Ocean \nb.  Atlantic Ocean \nc.  Pacific Ocean \nd.  Indian Ocean  \nAnswer: ")
if answer5=="c" or answer5=="Pacific Ocean":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Pacific Ocean.")
    #print("Score :", score)
    print("\n")
    
#Question 6
answer6 = input("Q6. How many Planets are there in Solar Sytem? \na.  7 \nb.  8 \nc.  9 \nd.  6  \nAnswer: ")
if answer6=="b" or answer6=="8":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is 8.")
    #print("Score :", score)
    print("\n")
    
#Question 7
answer7 = input("Q7. Who invented Telephone? \na.  Newton \nb.  Henry Ford \nc.  Graham Bell \nd.  Thomas Edison  \nAnswer: ")
if answer7=="c" or answer7=="Graham Bell":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Graham Bell.")
    #print("Score :", score)
    print("\n")
    
#Question 8
answer8 = input("Q8. What is the National Animal of India? \na.  Tiger \nb.  Lion \nc.  Penguin \nd.  Cheetah  \nAnswer: ")
if answer8=="a" or answer8=="Tiger":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Tiger.")
    #print("Score :", score)
    print("\n")
    
#Question 9
answer9 = input("Q9. Joule is the unit of? \na.  Temperature \nb.  Pressure \nc.  Energy \nd.  Heat  \nAnswer: ")
if answer9=="c" or answer9=="Energy":
    score=score+1
    print("Answer is correct !")
    #print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Energy.")
   # print("Score :", score)
    print("\n")
    
#Question 10
answer10 = input("Q10. National Defence Academy is situated at? \na.  Khadakvasla \nb.  New Delhi \nc.  Wellington \nd.  Dehradun  \nAnswer: ")
if answer10=="a" or answer4=="Khadakvasla":
    score=score+1
    print("Answer is correct !")
   # print("Score:", score)
    print("\n")
else:
    print("Answer is incorrect ! The correct answer is Khadakvasla.")
    #print("Score :", score)
    print("\n")

# Final Message
if score<=5:
    print("Your total score is:", score, "-Needs improvement")
elif score >=6 and score<=8:
    print("Your total score is:", score, "- Very Good")
else:
    print("Your total score is:", score, "-Excellent")
# Out:
# Q1. What is capital of India?
# a.  Mumbai
# b.  New Delhi
# c.  Kolkata
# d.  Chennai
# Answer: a
# Answer is incorrect ! The correct answer is New Delhi.
#
#
# Q2. Who is President of India?
# a.  Narendra Modi
# b.  Ram Nath Kovind
# c.  Sonia Gandhi
# d.  Arvind Kejriwal
# Answer: a
# Answer is incorrect ! The correct answer is Ram Nath Kovind.
#
#
# Q3. Where Gateway Of India is Located?
# a.  Mumbai
# b.  Bangalore
# c.  Hyderabad
# d.  Lucknow
# Answer: Mumbai
# Answer is incorrect ! The correct answer is Mumbai.
#
#
# Q4. Which is the smallest continent?
# a.  Asia
# b.  Antartica
# c.  North America
# d.  Australia
# Answer: d
# Answer is correct !
#
#
# Q5. Which is the largest ocean in the world?
# a.  Arctic Ocean
# b.  Atlantic Ocean
# c.  Pacific Ocean
# d.  Indian Ocean
# Answer: d
# Answer is incorrect ! The correct answer is Pacific Ocean.
#
#
# Q6. How many Planets are there in Solar Sytem?
# a.  7
# b.  8
# c.  9
# d.  6
# Answer: 8
# Answer is correct !
#
#
# ...
