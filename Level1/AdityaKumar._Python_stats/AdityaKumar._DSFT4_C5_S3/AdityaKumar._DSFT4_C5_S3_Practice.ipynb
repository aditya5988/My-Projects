# %% [markdown]
# # TASK 1
# P(A)=.46
# P(B)=.174
# P(A and B)= .25
# P(A/B)=(.46*.25)/.174=.66

# %% [markdown]
# # TASK 2
#
# P(A)=.70
# P(B)=.67
# P(A and B)= .56
# P(B/A)=(.56/.70)=0.8

# %%
# Task 3
import pandas as pd
df=pd.read_csv('DS1_C5_S3_Sampling_Practice_GamesSales_Data.csv')
df
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %%
# Task 3.1.1
# Random Sampling without replacement
game_df=df.sample(n=30, random_state=1)
game_df
# Out:
#                                                   Game  Year  \
# 189                           One Piece: Burning Blood  2018
# 111                                           WWE 2K18  2019
# 551                         Sengoku Basara 4: Sumeragi  2017
# 429  Earth Defense Force 2025.1: The Shadow of New ...  2017
# 666                                 This Is The Police  2019
# 537                                 Starblood Arena VR  2019
# 686                            Battle Garegga Rev.2018  2018
# 139                                              Ni-Oh  2019
# 69                         Dragon Age III: Inquisition  2016
# 335                        Dynasty Warriors 8: Empires  2016
# 47                        Resident Evil VII: Biohazard  2019
# 642                            Super Stardust Ultra VR  2018
# 274                 Dynasty Warriors 8: Xtreme Legends  2016
# 172           Disney Infinity 2.0: Marvel Super Heroes  2016
# ...

# %%
# Task 3.1.2
# Random Sampling with replacement
game_df1=df.sample(n=30, replace=True , random_state=1)
game_df1
# Out:
#                                                   Game  Year  \
# 37                                           Far Cry 5  2020
# 235                                  Tales of Zestiria  2017
# 72                             Need for Speed: Payback  2019
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018
# 144                           Injustice: Gods Among Us  2015
# 129                                        LEGO Worlds  2019
# 583                                         Dungeons 3  2019
# 508                    Dead or Alive Xtreme 3: Fortune  2018
# 390                                             MXGP 2  2018
# 281                                       Yooka-Laylee  2019
# 178                           The LEGO Movie Videogame  2016
# 276                        Saint Seiya: Soldiers' Soul  2017
# 254                                             Vampyr  2020
# 357           MXGP 3: The Official Motocross Videogame  2019
# ...

# %%
# Task 3.1.3
# Systemic sampling
import numpy as np
indexes=np.arange(0,len(df),step=50)
df.iloc[indexes]
# Out:
#                                                   Game  Year         Genre  \
# 0                                   Grand Theft Auto V  2016        Action
# 50                      Middle-Earth: Shadow of Mordor  2016        Action
# 100           Naruto Shippuden: Ultimate Ninja Storm 4  2018      Fighting
# 150                    Ni no Kuni II: Revenant Kingdom  2020  Role-Playing
# 200             Dragon Quest Builders: Revive Alefgard  2018  Role-Playing
# 250                                          Tropico 5  2017    Simulation
# 300                                     Darksiders III  2020        Action
# 350  The Walking Dead - The Telltale Series: A New ...  2019     Adventure
# 400                                     Akiba's Trip 2  2016        Action
# 450                                   The Technomancer  2018  Role-Playing
# 500              Warhammer: The End Times - Vermintide  2018        Action
# ...

# %%
# Task 3.1.4
# Strafied sampling
grouped_d_df=df.groupby(['Year'])['Genre'].value_counts()
grp_df=df.groupby(['Year','Genre'])
Strat_Sample_df=pd.DataFrame()
for y in grouped_d_df.index:
    d_data=grp_df.get_group(y)
    sample_data=d_data.sample(n=30,replace=True,random_state=1)
    Strat_Sample_df=Strat_Sample_df.append(sample_data, ignore_index=True)
    
Strat_Sample_df
# Out:
#                 Game  Year     Genre        Publisher  North_America_Sales_M$  \
# 0           NBA 2K14  2015    Sports        2K Sports                    0.91
# 1        NBA Live 14  2015    Sports        EA Sports                    0.17
# 2     FIFA Soccer 14  2015    Sports        EA Sports                    0.62
# 3     FIFA Soccer 14  2015    Sports        EA Sports                    0.62
# 4        NBA Live 14  2015    Sports        EA Sports                    0.17
# ...              ...   ...       ...              ...                     ...
# 2485         Armello  2020  Strategy  League of Geeks                    0.02
# 2486         Armello  2020  Strategy  League of Geeks                    0.02
# 2487         Armello  2020  Strategy  League of Geeks                    0.02
# 2488         Armello  2020  Strategy  League of Geeks                    0.02
# 2489         Armello  2020  Strategy  League of Geeks                    0.02
#
# ...

# %%
# Task 3.1.5
# Clustered sampling
grouped_year_df=df.groupby(['Year'])
years=[2016, 2019]
C_sample_df=pd.DataFrame()
for y in years:
    year_data=grouped_year_df.get_group(y)
    sample_data=year_data.sample(frac=.1 , random_state=1)
    C_sample_df=C_sample_df.append(sample_data, ignore_index=True)
    
C_sample_df
# Out:
#                                                  Game  Year             Genre  \
# 0                 Lara Croft and the Temple of Osiris  2016            Action
# 1                                           Teslagrad  2016          Platform
# 2                                       Trials Fusion  2016              Misc
# 3                                             Thief 4  2016            Action
# 4                                       The Golf Club  2016            Sports
# 5                                 Tour de France 2016  2016            Sports
# 6                                   Warriors Orochi 3  2016            Action
# 7                                      Bound By Flame  2016            Action
# 8   Yahari Game Demo Ore no Seishun Love-Kome wa M...  2019         Adventure
# 9                                   The Town of Light  2019         Adventure
# 10                                   Agents of Mayhem  2019            Action
# ...

# %%
grouped_genre_df1=df.groupby(['Genre'])
genres=['Action','Adventure']
C_sample_df1=pd.DataFrame()
for g in genres:
    genre_data=grouped_genre_df1.get_group(g)
    sample_data=genre_data.sample(frac=.1 , random_state=1)
    C_sample_df1=C_sample_df.append(sample_data, ignore_index=True)
    
C_sample_df1
# Out:
#                                                  Game  Year             Genre  \
# 0                 Lara Croft and the Temple of Osiris  2016            Action
# 1                                           Teslagrad  2016          Platform
# 2                                       Trials Fusion  2016              Misc
# 3                                             Thief 4  2016            Action
# 4                                       The Golf Club  2016            Sports
# 5                                 Tour de France 2016  2016            Sports
# 6                                   Warriors Orochi 3  2016            Action
# 7                                      Bound By Flame  2016            Action
# 8   Yahari Game Demo Ore no Seishun Love-Kome wa M...  2019         Adventure
# 9                                   The Town of Light  2019         Adventure
# 10                                   Agents of Mayhem  2019            Action
# ...

# %%
# Task 3.2.1

sample_data10=df.sample(n=10, replace=True, random_state=1)
sample_data20=df.sample(n=20, replace=True, random_state=1)
sample_data30=df.sample(n=30, replace=True, random_state=1)
print("Game data with sample size 10 ",sample_data10)
print("Game data with sample size 20 ",sample_data20)
print("Game data with sample size 30 ",sample_data30)
# Out:
# Game data with sample size 10                                                    Game  Year         Genre  \
# 37                                           Far Cry 5  2020        Action
# 235                                  Tales of Zestiria  2017  Role-Playing
# 72                             Need for Speed: Payback  2019        Racing
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018        Action
# 144                           Injustice: Gods Among Us  2015      Fighting
# 129                                        LEGO Worlds  2019          Misc
# 583                                         Dungeons 3  2019      Strategy
# 508                    Dead or Alive Xtreme 3: Fortune  2018        Sports
# 390                                             MXGP 2  2018        Racing
# 281                                       Yooka-Laylee  2019      Platform
#
#                                   Publisher  North_America_Sales_M$  \
# ...

# %%
import statistics as st
import scipy.stats as sts

# %%
sample_mean10=st.mean(sample_data10['Global_Sales_M$'])
sample_sd10=st.stdev(sample_data10['Global_Sales_M$'])
sample_median10=st.median(sample_data10['Global_Sales_M$'])
print("Mean of game data with 10 sample space =",sample_mean10)
print("Sd of game data with 10 sample space =",sample_sd10)
print("Median of game data with 10 sample space = ",sample_median10)

sample_mean20=st.mean(sample_data20['Global_Sales_M$'])
sample_sd20=st.stdev(sample_data20['Global_Sales_M$'])
sample_median20=st.median(sample_data20['Global_Sales_M$'])
print("Mean of game data with 20 sample space =",sample_mean20)
print("Sd of game data with 20 sample space =",sample_sd20)
print("Median of game data with 20 sample space = ",sample_median20)

sample_mean30=st.mean(sample_data30['Global_Sales_M$'])
sample_sd30=st.stdev(sample_data30['Global_Sales_M$'])
sample_median30=st.median(sample_data30['Global_Sales_M$'])
print("Mean of game data with 30 sample space =",sample_mean30)
print("Sd of game data with 30 sample space =",sample_sd30)
print("Median of game data with 30 sample space = ",sample_median30)

# %%
# Task 3.2.2
sample_mean_pop=st.mean(game_df['Global_Sales_M$'])
sample_sd_pop=st.stdev(game_df['Global_Sales_M$'])
sample_median_pop=st.median(game_df['Global_Sales_M$'])
print("Mean of game data with population data =",sample_mean_pop)
print("Sd of game data with population data =",sample_sd_pop)
print("Median of game data with population data = ",sample_median_pop)

# %%
# Task 3.2.3
import matplotlib.pyplot as plt
plt.hist(game_df['Global_Sales_M$'],bins=5)
plt.title('Population Data')
plt.show()

# %%
plt.hist(sample_data10['Global_Sales_M$'],bins=5)
plt.title('Sample Data for 10 samples')
plt.show()

# %%
plt.hist(sample_data20['Global_Sales_M$'],bins=5)
plt.title('Sample Data for 20 samples')
plt.show()

# %%
plt.hist(sample_data30['Global_Sales_M$'],bins=5)
plt.title('Sample Data for 30 samples')
plt.show()

# %%
print(" Conclusion : It can be concluded after looking at the distribution shape that as the sample data increases the sample data graph becomes becomes more similar to the Population data graph")
# Out:
#  Conclusion : It can be concluded after looking at the distribution shape that as the sample data increases the sample data graph becomes becomes more similar to the Population data graph
