# %%
import sys
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %%
url='https://store.steampowered.com/search/results/?query&start=0&count=50&dynamic_data=&sort_by=_ASC&snr=1_7_7_7000_7&filter=topsellers&infinite=1'

# %%
response1 = requests.get(url)
response1.status_code
# Out:
# 200

# %%
soup1 = BeautifulSoup(response1.content, 'lxml')
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
#authors = soup1.find_all('span')
#authors

# %%
def totalresults(url):
    r = requests.get(url)
    data = dict(r.json())
    totalresults = data['total_count']
    return int(totalresults)

# %%
def get_data(url):
    r = requests.get(url)
    data = dict(r.json())
    return data['results_html']

print(get_data(url))
# Out:
# <!-- List Items -->
#
# 				<a href="https://store.steampowered.com/app/1245620/ELDEN_RING/?snr=1_7_7_7000_150_1"
# 			 data-ds-appid="1245620" data-ds-itemkey="App_1245620" data-ds-tagids="[29482,4604,122,1654,4026,4231,1697]" data-ds-descids="[2,5]" data-ds-crtrids="[33042543]" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:1245620,&quot;public&quot;:1,&quot;v6&quot;:1} );" onmouseout="HideGameHover( this, event, 'global_hover' )" class="search_result_row ds_collapse_flag "
# 		   data-search-page="1" data-gpnav="item"
# 		   data-ds-steam-deck-compat-handled="true">
#             <div class="col search_capsule"><img src="https://cdn.akamai.steamstatic.com/steam/apps/1245620/capsule_sm_120.jpg?t=1646406355" srcset="https://cdn.akamai.steamstatic.com/steam/apps/1245620/capsule_sm_120.jpg?t=1646406355 1x, https://cdn.akamai.steamstatic.com/steam/apps/1245620/capsule_231x87.jpg?t=1646406355 2x"></div>
# ...

# %%
# Task 1
def parse(data):
    gameslist = []
    soup= BeautifulSoup(data, 'lxml')
    games=soup.find_all('a')
    for game in games:
        title = game.find('span', class_='title').text
        price = game.find('div' , class_='search_price').text.strip().split('₹')[1]
        #discprice = game.find('div' , class_='search_price').text.strip().split('₹')[2]
        release=game.find('div' , class_='search_released').text
        
        try:
            discprice = game.find('div' , class_='search_price').text.strip().split('₹')[2]
        except:
            discprice=price
            
       
        print(title, price, discprice, release)
        
        mygame={
            'title' : title,
            'price' : price,
            'discprice' : discprice,
            'relase date' : release
            
            
        }
        
        gameslist.append(mygame)
    return gameslist

def output(gameslist):
    gamesdf=pd.concat([pd.DataFrame(g) for g in results])
    #gamesdf.to_csv('gamesprices.csv', index= False)
    #print('Fin. Saved to CSV')
    print(gamesdf)
    return

data = get_data(url)
gameslist = parse(data)
output(gameslist)
#print(totalresults(url))
# Out:
# ELDEN RING  2,499  2,499 24 Feb, 2022
# Dread Hunger  875  875 26 Jan, 2022
# Risk of Rain 2: Survivors of the Void  349  226 1 Mar, 2022
# Project Zomboid  529  529 8 Nov, 2013
# Dying Light 2 Stay Human  2,999  2,999 3 Feb, 2022
# Risk of Rain 2  719  359 11 Aug, 2020
# Fall Guys: Ultimate Knockout  529  211 3 Aug, 2020
# Risk of Rain 2 + Survivors of the Void Expansion  1,068  585
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# CS:GO Prime Status Upgrade  1,140  1,140 21 Aug, 2012
# Wallpaper Engine  229  229 Nov 2018
# Overcooked! 2  569  142 7 Aug, 2018
# Grand Theft Auto V: Premium Edition  1,978  1,978
# Ready or Not  1,299  1,299 17 Dec, 2021
# Total War: WARHAMMER III  3,399  3,399 16 Feb, 2022
# Destiny 2: The Witch Queen  899  899 22 Feb, 2022
# Human: Fall Flat  529  179 22 Jul, 2016
# Vampire Survivors  125  125 17 Dec, 2021
# It Takes Two  2,499  2,499 25 Mar, 2021
# ...

# %%
# Task 2
results = []
for x in range(0, 2000, 50):
    data = get_data(f'https://store.steampowered.com/search/results/?query&start={x}&count=50&dynamic_data=&sort_by=_ASC&snr=1_7_7_7000_7&filter=topsellers&infinite=1')
    results.append(parse(data))
    print('Results Scraped:', x)
output(results)
# Out:
# ELDEN RING  2,499  2,499 24 Feb, 2022
# Dread Hunger  875  875 26 Jan, 2022
# Risk of Rain 2: Survivors of the Void  349  226 1 Mar, 2022
# Project Zomboid  529  529 8 Nov, 2013
# Dying Light 2 Stay Human  2,999  2,999 3 Feb, 2022
# Risk of Rain 2  719  359 11 Aug, 2020
# Fall Guys: Ultimate Knockout  529  211 3 Aug, 2020
# Risk of Rain 2 + Survivors of the Void Expansion  1,068  585
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# CS:GO Prime Status Upgrade  1,140  1,140 21 Aug, 2012
# Wallpaper Engine  229  229 Nov 2018
# Overcooked! 2  569  142 7 Aug, 2018
# Grand Theft Auto V: Premium Edition  1,978  1,978
# Ready or Not  1,299  1,299 17 Dec, 2021
# Total War: WARHAMMER III  3,399  3,399 16 Feb, 2022
# Destiny 2: The Witch Queen  899  899 22 Feb, 2022
# Human: Fall Flat  529  179 22 Jul, 2016
# Vampire Survivors  125  125 17 Dec, 2021
# It Takes Two  2,499  2,499 25 Mar, 2021
# ...

# %%
# Task 5
results = []
for x in range(0, 350, 50):
    data = get_data(f'https://store.steampowered.com/search/results/?query&start={x}&count=50&dynamic_data=&sort_by=_ASC&snr=1_7_7_7000_7&filter=topsellers&infinite=1')
    results.append(parse(data))
    #print('Results Scraped:', x)
output(results)
# Out:
# ELDEN RING  2,499  2,499 24 Feb, 2022
# Dread Hunger  875  875 26 Jan, 2022
# Risk of Rain 2: Survivors of the Void  349  226 1 Mar, 2022
# Project Zomboid  529  529 8 Nov, 2013
# Dying Light 2 Stay Human  2,999  2,999 3 Feb, 2022
# Risk of Rain 2  719  359 11 Aug, 2020
# Fall Guys: Ultimate Knockout  529  211 3 Aug, 2020
# Risk of Rain 2 + Survivors of the Void Expansion  1,068  585
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# WWE 2K22  3,299  3,299 11 Mar, 2022
# CS:GO Prime Status Upgrade  1,140  1,140 21 Aug, 2012
# Wallpaper Engine  229  229 Nov 2018
# Overcooked! 2  569  142 7 Aug, 2018
# Grand Theft Auto V: Premium Edition  1,978  1,978
# Ready or Not  1,299  1,299 17 Dec, 2021
# Total War: WARHAMMER III  3,399  3,399 16 Feb, 2022
# Destiny 2: The Witch Queen  899  899 22 Feb, 2022
# Human: Fall Flat  529  179 22 Jul, 2016
# Vampire Survivors  125  125 17 Dec, 2021
# It Takes Two  2,499  2,499 25 Mar, 2021
# ...

# %%
response1=requests.get(url)
soup=BeautifulSoup(response1.content, 'lxml')
tags = soup.find_all('img')
for tag in tags:
    print(tag.get('src'))
# Out:
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1245620\/capsule_sm_120.jpg?t=1646406355\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1418630\/capsule_sm_120.jpg?t=1644505013\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1607890\/capsule_sm_120.jpg?t=1646153758\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/108600\/capsule_sm_120.jpg?t=1644611871\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/534380\/capsule_sm_120.jpg?t=1645792973\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/632360\/capsule_sm_120.jpg?t=1646153779\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1097150\/capsule_sm_120.jpg?t=1645126741\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/bundles\/24815\/q7b85b5ec2axaicj\/capsule_sm_120.jpg?t=1646150648\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1255630\/capsule_sm_120.jpg?t=1646066176\"
# \"https:\/\/cdn.akamai.steamstatic.com\/steam\/apps\/1255630\/capsule_sm_120.jpg?t=1646066176\"
# ...

# %%
# Task 6
img_game1=requests.get("https://cdn.akamai.steamstatic.com/steam/apps/1245620/capsule_sm_120.jpg?t=1646406355")
open('img_game1.jpg', 'wb').write(img_game1.content)
img_game2=requests.get("https://cdn.akamai.steamstatic.com/steam/apps/108600/capsule_sm_120.jpg?t=1644611871")
open('img_game2.jpg', 'wb').write(img_game2.content)
img_game5=requests.get("https://cdn.akamai.steamstatic.com/steam/apps/1097150/capsule_sm_120.jpg?t=1645126741")
open('img_game5.jpg', 'wb').write(img_game5.content)
# Out:
# 3692

# %%
url = "https://store.steampowered.com"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="responsive" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="#171a21" name="theme-color"/>
# <title>Welcome to Steam</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=Rc2hpzg2Ex3T&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=7osXnMYyq5rM&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=6PFqex5UPprb&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/css/v6/store.css?v=9qpnDZtFMn1Y&amp;l=english" rel="stylesheet" type="text/css"/>
# ...

# %%
game = soup.div
game
# Out:
# <div class="responsive_page_frame with_header">
# <div class="responsive_page_menu_ctn mainmenu">
# <div class="responsive_page_menu" id="responsive_page_menu">
# <div class="mainmenu_contents">
# <div class="mainmenu_contents_items">
# <a class="menuitem" href="https://store.steampowered.com/login/?redir=&amp;redir_ssl=1&amp;snr=1_4_4__global-header">
# 									Login								</a>
# <a class="menuitem supernav" data-tooltip-content=".submenu_store" data-tooltip-type="selector" href="https://store.steampowered.com/?snr=1_4_4__global-responsive-menu">
# 		Store	</a>
# <div class="submenu_store" data-submenuid="store" style="display: none;">
# <a class="submenuitem" href="https://store.steampowered.com/?snr=1_4_4__global-responsive-menu">Home</a>
# <a class="submenuitem" href="https://store.steampowered.com/explore/?snr=1_4_4__global-responsive-menu">Discovery Queue</a>
# <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">Wishlist</a>
# ...

# %%
# Task 3
trend=soup.find('div' , class_='tab_item_top_tags')
trends=[]
for i in trend:
    trends.append(i.text)
trends

y= pd.DataFrame(trends, columns=['trends'])
y
# Out:
#                     trends
# 0                      RPG
# 1  , Traditional Roguelike
# 2                , Fantasy
# 3             , Open World

# %%
print("RPG Genre is the most preferred ")
# Out:
# RPG Genre is the most preferred

# %%
# Task 4
url_3 = "https://store.steampowered.com/search/?sort_by=_ASC&filter=topsellers"

html_content_3 = requests.get(url_3)

soup_3 = BeautifulSoup(html_content_3.content)

soup_3
# Out:
# <!DOCTYPE html>
# <html class="responsive" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="#171a21" name="theme-color"/>
# <title>Steam Search</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=Rc2hpzg2Ex3T&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=7osXnMYyq5rM&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=6PFqex5UPprb&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/css/v6/store.css?v=zNZYs5OwbWXG&amp;l=english" rel="stylesheet" type="text/css"/>
# ...

# %%
titles=soup_3.find_all('span',class_="title")

# %%
games_title= [title.text for title in titles]

# %%
price=soup_3.find_all('div',class_="col search_price responsive_secondrow")

# %%
price_text= [x.text.strip() for x in price]

# %%
games=pd.DataFrame(games_title,columns=['games_title'])

# %%
prices = pd.DataFrame(price_text, columns=['price_text'])

# %%
df=pd.concat([games, prices], axis=1)
df
# Out:
#                                           games_title price_text
# 0                                          ELDEN RING    ₹ 2,499
# 1                                        Dread Hunger      ₹ 875
# 2               Risk of Rain 2: Survivors of the Void      ₹ 529
# 3                                     Project Zomboid    ₹ 2,999
# 4                            Dying Light 2 Stay Human    ₹ 3,299
# 5                                      Risk of Rain 2    ₹ 3,299
# 6                        Fall Guys: Ultimate Knockout    ₹ 3,299
# 7    Risk of Rain 2 + Survivors of the Void Expansion    ₹ 1,140
# 8                                            WWE 2K22      ₹ 229
# 9                                            WWE 2K22    ₹ 1,978
# 10                                           WWE 2K22    ₹ 1,299
# 11                         CS:GO Prime Status Upgrade    ₹ 3,399
# 12                                   Wallpaper Engine      ₹ 899
# ...

# %%
df_final_top = pd.DataFrame(top, columns = ["TITLES/RANKINGS"])
df_final_top.value_counts()
# Out:
# TITLES/RANKINGS
# WWE 2K22                                                              3
# LEGO® Star Wars™: The Skywalker Saga                                  2
# CS:GO Prime Status Upgrade                                            1
# Risk of Rain 2 + Survivors of the Void Expansion                      1
# Overcooked! 2                                                         1
# Phasmophobia                                                          1
# Project Zomboid                                                       1
# Pummel Party                                                          1
# Raft                                                                  1
# Ready or Not                                                          1
# Red Dead Redemption 2                                                 1
# Risk of Rain 2                                                        1
# Risk of Rain 2: Survivors of the Void                                 1
# ...

# %%
df2=pd.concat([df, df_final_top], axis=1)
df2
# Out:
#                                           games_title price_text  \
# 0                                          ELDEN RING    ₹ 2,499
# 1                                        Dread Hunger      ₹ 875
# 2               Risk of Rain 2: Survivors of the Void      ₹ 529
# 3                                     Project Zomboid    ₹ 2,999
# 4                            Dying Light 2 Stay Human    ₹ 3,299
# 5                                      Risk of Rain 2    ₹ 3,299
# 6                        Fall Guys: Ultimate Knockout    ₹ 3,299
# 7    Risk of Rain 2 + Survivors of the Void Expansion    ₹ 1,140
# 8                                            WWE 2K22      ₹ 229
# 9                                            WWE 2K22    ₹ 1,978
# 10                                           WWE 2K22    ₹ 1,299
# 11                         CS:GO Prime Status Upgrade    ₹ 3,399
# 12                                   Wallpaper Engine      ₹ 899
# ...
