# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
# TASK 1
# a)

def tanh(x):
    ''' It returns the value (1-exp(-2x))/(1+exp(-2x)) and the value returned will be lies in between -1 to 1.'''
    return np.tanh(x)

# %%
x = np.linspace(-10, 10)
plt.plot(x, tanh(x))
plt.axis('tight')
plt.title('Activation Function :Tanh')
plt.show()

# %%
# b)

def sigmoid(x):
    ''' It returns 1/(1+exp(-x)). where the values lies between zero and one '''
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-10,10)
plt.plot(x, sigmoid(x))
plt.title('Activation Function :Sigmoid')
# plt.axis('tight')
plt.show()

# %%
# c)

def softmax(x):
    ''' Compute softmax values for each sets of scores in x. 
    Softmax turns logits, the numeric output of the last linear layer 
    of a multi-class classification neural network into probabilities.'''
    return np.exp(x) / np.sum(np.exp(x), axis=0)

# %%
x = np.linspace(-10,10)
plt.plot(x, softmax(x))
plt.title('Activation Function :Softmax')
plt.show()

# %%
# d)

def custom_activation(x):
  return(3*x**2+5)

# %%
# TASK 2
min_val = -15
max_val = 15
num_points = 130
x = np.linspace(min_val, max_val, num_points)
x
# Out:
# array([-15.        , -14.76744186, -14.53488372, -14.30232558,
#        -14.06976744, -13.8372093 , -13.60465116, -13.37209302,
#        -13.13953488, -12.90697674, -12.6744186 , -12.44186047,
#        -12.20930233, -11.97674419, -11.74418605, -11.51162791,
#        -11.27906977, -11.04651163, -10.81395349, -10.58139535,
#        -10.34883721, -10.11627907,  -9.88372093,  -9.65116279,
#         -9.41860465,  -9.18604651,  -8.95348837,  -8.72093023,
#         -8.48837209,  -8.25581395,  -8.02325581,  -7.79069767,
#         -7.55813953,  -7.3255814 ,  -7.09302326,  -6.86046512,
#         -6.62790698,  -6.39534884,  -6.1627907 ,  -5.93023256,
#         -5.69767442,  -5.46511628,  -5.23255814,  -5.        ,
#         -4.76744186,  -4.53488372,  -4.30232558,  -4.06976744,
#         -3.8372093 ,  -3.60465116,  -3.37209302,  -3.13953488,
#         -2.90697674,  -2.6744186 ,  -2.44186047,  -2.20930233,
#         -1.97674419,  -1.74418605,  -1.51162791,  -1.27906977,
#         -1.04651163,  -0.81395349,  -0.58139535,  -0.34883721,
#         -0.11627907,   0.11627907,   0.34883721,   0.58139535,
#          0.81395349,   1.04651163,   1.27906977,   1.51162791,
#          1.74418605,   1.97674419,   2.20930233,   2.44186047,
#          2.6744186 ,   2.90697674,   3.13953488,   3.37209302,
#          3.60465116,   3.8372093 ,   4.06976744,   4.30232558,
#          4.53488372,   4.76744186,   5.        ,   5.23255814,
#          5.46511628,   5.69767442,   5.93023256,   6.1627907 ,
#          6.39534884,   6.62790698,   6.86046512,   7.09302326,
#          7.3255814 ,   7.55813953,   7.79069767,   8.02325581,
#          8.25581395,   8.48837209,   8.72093023,   8.95348837,
#          9.18604651,   9.41860465,   9.65116279,   9.88372093,
#         10.11627907,  10.34883721,  10.58139535,  10.81395349,
#         11.04651163,  11.27906977,  11.51162791,  11.74418605,
#         11.97674419,  12.20930233,  12.44186047,  12.6744186 ,
#         12.90697674,  13.13953488,  13.37209302,  13.60465116,
#         13.8372093 ,  14.06976744,  14.30232558,  14.53488372,
#         14.76744186,  15.        ])

# %%
y = softmax(x)
train_data =x.reshape(num_points, 1)
label = y.reshape(num_points, 1)

plt.scatter(train_data, label)
plt.show()

# %%
# !pip install neurolab
# Out:
# Collecting neurolab
#   Downloading neurolab-0.3.5.tar.gz (645 kB)
#      |████████████████████████████████| 645 kB 7.0 MB/s
# Building wheels for collected packages: neurolab
#   Building wheel for neurolab (setup.py) ... done
#   Created wheel for neurolab: filename=neurolab-0.3.5-py3-none-any.whl size=22180 sha256=6c834c85a284d32d25d1361ee0cb0df9d855b1b39d25a35621cdf8eb8c811105
#   Stored in directory: /root/.cache/pip/wheels/3e/07/63/e3d6e066089d7186465184a6f9a1884471485f38beef1edeaa
# Successfully built neurolab
# Installing collected packages: neurolab
# Successfully installed neurolab-0.3.5

# %%
import neurolab as nl

nn = nl.net.newff([[min_val,max_val]],[10,6,1])

nn.trainf = nl.train.train_gd

error_progress = nn.train(train_data, label, epochs=2000, show=100, goal=0.01)

output = nn.sim(train_data)
y_pred = output.reshape(num_points)
# Out:
# Epoch: 100; Error: 0.6299492448598496;
# Epoch: 200; Error: 0.07482936584927448;
# Epoch: 300; Error: 0.15065895951668426;
# Epoch: 400; Error: 0.1019457246517858;
# Epoch: 500; Error: 0.038057869800018115;
# Epoch: 600; Error: 0.040749124989716036;
# Epoch: 700; Error: 0.053068429202775574;
# Epoch: 800; Error: 0.04264059244849312;
# Epoch: 900; Error: 0.03499989422709231;
# Epoch: 1000; Error: 0.03367313257285281;
# Epoch: 1100; Error: 0.031829786804804444;
# Epoch: 1200; Error: 0.028503966273133285;
# Epoch: 1300; Error: 0.025916939225763835;
# Epoch: 1400; Error: 0.024239912631962547;
# Epoch: 1500; Error: 0.022750008073276283;
# Epoch: 1600; Error: 0.021263040739490188;
# Epoch: 1700; Error: 0.019961948259910125;
# Epoch: 1800; Error: 0.01891127341211543;
# Epoch: 1900; Error: 0.01803077132108337;
# Epoch: 2000; Error: 0.017244605217646015;
# The maximum number of train epochs is reached

# %%
plt.figure()
plt.plot(error_progress)
plt.xlabel('Number of epochs')
plt.ylabel('Error')
plt.title('Train error progress')
plt.show()

# %%
# Plot input data

x_dense = np.linspace(min_val, max_val, num_points*2)
y_dense_pred = nn.sim(x_dense.reshape(x_dense.size,1)).reshape(x_dense.size)
plt.figure()
plt.plot(x_dense, y_dense_pred, '-',x,y, '-', x, y_pred, 'p')
plt.title('Actual vs predicted')
plt.show()

# %%
# For tanh
y = tanh(x)
train_data =x.reshape(num_points, 1)
label = y.reshape(num_points, 1)

plt.scatter(train_data, label)
plt.show()

# %%
nn = nl.net.newff([[min_val,max_val]],[10,6,1])

nn.trainf = nl.train.train_gd

error_progress = nn.train(train_data, label, epochs=2000, show=100, goal=0.01)

output = nn.sim(train_data)
y_pred = output.reshape(num_points)
# Out:
# Epoch: 100; Error: 0.031091137020197508;
# Epoch: 200; Error: 0.01929462365311798;
# Epoch: 300; Error: 0.015869180772335244;
# Epoch: 400; Error: 0.013954939365292036;
# Epoch: 500; Error: 0.012495337960975118;
# Epoch: 600; Error: 0.011275673388990316;
# Epoch: 700; Error: 0.010235226720291517;
# The goal of learning is reached

# %%
plt.figure()
plt.plot(error_progress)
plt.xlabel('Number of epochs')
plt.ylabel('Error')
plt.title('Train error progress')
plt.show()

# %%
# Plot input data

x_dense = np.linspace(min_val, max_val, num_points*2)
y_dense_pred = nn.sim(x_dense.reshape(x_dense.size,1)).reshape(x_dense.size)
plt.figure()
plt.plot(x_dense, y_dense_pred, '-',x,y, '-', x, y_pred, 'p')
plt.title('Actual vs predicted')
plt.show()
